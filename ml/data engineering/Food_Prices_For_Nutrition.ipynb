# %% [markdown]
# Food Prices For Nutrition Dataframe - Cost of a Nutriet Adequate Diet
#
# [Data Base](https://databank.worldbank.org/source/food-prices-for-nutrition)

# %%
import pandas as pd

file_path = 'test.csv'

# Attempt to read the CSV with a different encoding, e.g., 'ISO-8859-1'
try:
    df = pd.read_csv(file_path, encoding='ISO-8859-1')
except UnicodeDecodeError as e:
    print(f"Error reading file with ISO-8859-1 encoding: {e}")
    # Try another encoding
    try:
        df = pd.read_csv(file_path, encoding='cp1252')
    except UnicodeDecodeError as e:
        print(f"Error reading file with cp1252 encoding: {e}")
        # If you still encounter errors, consider trying 'utf-16' or another encoding

# Assuming you've successfully read the file
pd.set_option('display.max_rows', None)

df
# Out:
#                                Classification Name Classification Code  \
# 0                    Food Prices for Nutrition 2.0             FPN 2.0
# 1                    Food Prices for Nutrition 2.0             FPN 2.0
# 2                    Food Prices for Nutrition 2.0             FPN 2.0
# 3                    Food Prices for Nutrition 2.0             FPN 2.0
# 4                    Food Prices for Nutrition 2.0             FPN 2.0
# 5                    Food Prices for Nutrition 2.0             FPN 2.0
# 6                    Food Prices for Nutrition 2.0             FPN 2.0
# 7                    Food Prices for Nutrition 2.0             FPN 2.0
# 8                    Food Prices for Nutrition 2.0             FPN 2.0
# 9                    Food Prices for Nutrition 2.0             FPN 2.0
# 10                   Food Prices for Nutrition 2.0             FPN 2.0
# 11                   Food Prices for Nutrition 2.0             FPN 2.0
# ...
